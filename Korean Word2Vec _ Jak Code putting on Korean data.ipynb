# %%
import multiprocessing
from gensim.models.word2vec import LineSentence
from gensim.models import Word2Vec
from os import walk
from gensim.models.word2vec import Text8Corpus
from datetime import datetime
import time
import os

import logging


def train_and_test(root_train, root_test , output_name, params):
    
    logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
    directory = os.path.join("/home/snu/data/Kor_Test_data/models", datetime.now().strftime('%Y-%m-%d_%H-%M-%S'))
    os.makedirs(directory)
    test=open(directory+"/Kor test results.txt","w") ##replaced the 'directory' into real one
    startTime = time.time()
      
    print("\nRetrieving the corpus...")   
    #if using another corpus then use LineSentence() which will itterate over the corpus in root 
    #sentences = LineSentence(root)
    sentences = Text8Corpus(root_train)
    
    print("Training the model...")
    model = Word2Vec(sentences, **params)
    
    print("Freeing the memory...")
    model.init_sims(replace=True)
    
    print("saving the model...")
    model.save(directory+"/"+output_name)
    
    print("Testing the model...")
    test.write("Model " + output_name +  " at " + directory + ".\n")
    test.write("Training from : " + root_train + "\n")
    test.write("\n")
    endTime = time.time()
    test.write("Parameters : " + "\n\tVector size = " + repr(params["size"]) + ",\n\tWindow size = " + repr(params["window"]) + ",\n\tMin count = " + repr(params["min_count"]) + ",\n\tskip-gram/CBOW = " + ("skip-gram" if params["sg"]==1 else "CBOW") + ",\n\tHierarchical softmax/Negative sampling = " + ("Hierarchical softmax" if params["hs"]==1 else "Negative sampling \n\n"))
    test.write("The model took " + repr((endTime - startTime)/60)+ " to train." + "\n")
    test.write("Vocabulary length : " + repr(len(model.wv.vocab)) + "\n")
    test.write("\n\n") 
    test.write("Testing from : " + root_test + "\n\n")
    

    
    for (dirpath, dirnames, filenames) in walk(root_test):
        filenames = filenames
        break
    
    sim=0   
    sim2=0
    num_tests=len(filenames)   
    mw=0
    total_num_pairs=0
    
    for file in filenames:
        similarity = model.wv.evaluate_word_pairs(root_test+file, dummy4unknown=False)
        num_pairs=round(len(open(root_test+file,"r").readlines()))
        total_num_pairs=total_num_pairs + num_pairs
        sim=sim+similarity[0][0]
        sim2=sim2+similarity[1][0]
        mw=mw+similarity[2]*num_pairs/100
        test.write("Test results on " + file + ": \n")
        test.write("Pearson correlation coefficient = %.2f\n" % similarity[0][0])
        test.write("Spearman rank-order correlation coefficient = %.2f\n" % similarity[1][0])
        test.write("Number of missing words = " + repr(round(similarity[2]*num_pairs/100)) + "/" + repr(num_pairs)+ "\n")
        test.write("\n")
    
    test.write("Average test results: \n")    
    test.write("Average Pearson Correlation  = %.2f\n" % (sim/num_tests))
    test.write("Average Pearson Spearman rank-order correlation = %.2f\n" % (sim2/num_tests))
    test.write("Total number of missing words : "+repr(round(mw))+"/"+repr(total_num_pairs)+ "\n")

    test.close()
    
    return (sim/num_tests), (sim2/num_tests), (round(mw)), (total_num_pairs)

if __name__ == "__main__":
    
    
    output_name = "output_0"
    root_train = "/home/snu/data/Kor_Training_data/full.txt"
    root_test = "/home/snu/data/Kor_Test_data/kor_ws353.txt"
    
    params = {
        'size': 100,
        'window': 5,
        'min_count': 10,
        'sg' : 0,
        'hs' : 0,
        'workers': max(1, multiprocessing.cpu_count() - 1),
        'sample': 1E-3,
        }
    
    results = train_and_test(root_train, root_test, output_name, params)
    
    print("\nAverage test results: \n")    
    print("Average Pearson Correlation  = %.2f" % results[0])
    print("Average Pearson Spearman rank-order correlation = %.2f" % results[1])
    print("Total number of missing words : " + repr(results[2])+"/" + repr(results[3]))
# Out:
# 2017-07-23 16:43:00,909 : INFO : collecting all words and their counts
# 2017-07-23 16:43:00,912 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# Retrieving the corpus...
# Training the model...
# 2017-07-23 16:43:23,168 : INFO : collected 3220828 word types from a corpus of 44740290 raw words and 4475 sentences
# 2017-07-23 16:43:23,168 : INFO : Loading a fresh vocabulary
# 2017-07-23 16:43:24,780 : INFO : min_count=10 retains 266937 unique words (8% of original 3220828, drops 2953891)
# 2017-07-23 16:43:24,781 : INFO : min_count=10 leaves 39565473 word corpus (88% of original 44740290, drops 5174817)
# 2017-07-23 16:43:25,395 : INFO : deleting the raw counts dictionary of 3220828 items
# 2017-07-23 16:43:25,490 : INFO : sample=0.001 downsamples 19 most-common words
# 2017-07-23 16:43:25,491 : INFO : downsampling leaves estimated 34202262 word corpus (86.4% of prior 39565473)
# 2017-07-23 16:43:25,492 : INFO : estimated required memory for 266937 words and 100 dimensions: 347018100 bytes
# 2017-07-23 16:43:26,510 : INFO : resetting layer weights
# 2017-07-23 16:43:29,041 : INFO : training model with 7 workers on 266937 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2017-07-23 16:43:30,052 : INFO : PROGRESS: at 0.43% examples, 756722 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:43:31,059 : INFO : PROGRESS: at 0.88% examples, 755963 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:43:32,066 : INFO : PROGRESS: at 1.30% examples, 746965 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:43:33,078 : INFO : PROGRESS: at 1.73% examples, 743839 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:43:34,081 : INFO : PROGRESS: at 2.16% examples, 744890 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:43:35,082 : INFO : PROGRESS: at 2.59% examples, 745378 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:43:36,117 : INFO : PROGRESS: at 3.03% examples, 741706 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:43:37,141 : INFO : PROGRESS: at 3.47% examples, 742003 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:43:38,172 : INFO : PROGRESS: at 3.90% examples, 740425 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:43:39,175 : INFO : PROGRESS: at 4.33% examples, 740142 words/s, in_qsize 12, out_qsize 2
# 2017-07-23 16:43:40,197 : INFO : PROGRESS: at 4.77% examples, 740107 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:43:41,207 : INFO : PROGRESS: at 5.18% examples, 737341 words/s, in_qsize 14, out_qsize 2
# 2017-07-23 16:43:42,211 : INFO : PROGRESS: at 5.62% examples, 738133 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:43:43,244 : INFO : PROGRESS: at 6.06% examples, 737393 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:43:44,250 : INFO : PROGRESS: at 6.46% examples, 734615 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:43:45,250 : INFO : PROGRESS: at 6.89% examples, 734887 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:43:46,282 : INFO : PROGRESS: at 7.31% examples, 732552 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:43:47,285 : INFO : PROGRESS: at 7.72% examples, 731582 words/s, in_qsize 14, out_qsize 1
# 2017-07-23 16:43:48,340 : INFO : PROGRESS: at 8.15% examples, 729313 words/s, in_qsize 9, out_qsize 4
# 2017-07-23 16:43:49,350 : INFO : PROGRESS: at 8.59% examples, 730079 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:43:50,366 : INFO : PROGRESS: at 9.02% examples, 730205 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:43:51,371 : INFO : PROGRESS: at 9.44% examples, 729654 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:43:52,399 : INFO : PROGRESS: at 9.87% examples, 729146 words/s, in_qsize 13, out_qsize 2
# 2017-07-23 16:43:53,403 : INFO : PROGRESS: at 10.31% examples, 729729 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:43:54,424 : INFO : PROGRESS: at 10.74% examples, 729306 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:43:55,439 : INFO : PROGRESS: at 11.17% examples, 728937 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:43:56,456 : INFO : PROGRESS: at 11.60% examples, 728484 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:43:57,479 : INFO : PROGRESS: at 12.03% examples, 727851 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:43:58,483 : INFO : PROGRESS: at 12.47% examples, 728462 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:43:59,493 : INFO : PROGRESS: at 12.89% examples, 728090 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:44:00,516 : INFO : PROGRESS: at 13.31% examples, 727034 words/s, in_qsize 12, out_qsize 3
# 2017-07-23 16:44:01,523 : INFO : PROGRESS: at 13.76% examples, 727958 words/s, in_qsize 13, out_qsize 2
# 2017-07-23 16:44:02,541 : INFO : PROGRESS: at 14.21% examples, 728625 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:44:03,572 : INFO : PROGRESS: at 14.64% examples, 728132 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:44:04,587 : INFO : PROGRESS: at 15.07% examples, 727808 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:44:05,588 : INFO : PROGRESS: at 15.49% examples, 727420 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:44:06,616 : INFO : PROGRESS: at 15.94% examples, 727781 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:44:07,620 : INFO : PROGRESS: at 16.35% examples, 727051 words/s, in_qsize 10, out_qsize 3
# 2017-07-23 16:44:08,628 : INFO : PROGRESS: at 16.80% examples, 727484 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:44:09,632 : INFO : PROGRESS: at 17.24% examples, 727787 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:44:10,637 : INFO : PROGRESS: at 17.68% examples, 728365 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:44:11,649 : INFO : PROGRESS: at 18.12% examples, 728423 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:44:12,656 : INFO : PROGRESS: at 18.56% examples, 728672 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:44:13,681 : INFO : PROGRESS: at 19.01% examples, 728863 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:44:14,683 : INFO : PROGRESS: at 19.46% examples, 729634 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:44:15,695 : INFO : PROGRESS: at 19.92% examples, 730416 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:44:16,723 : INFO : PROGRESS: at 20.38% examples, 731554 words/s, in_qsize 13, out_qsize 2
# 2017-07-23 16:44:17,724 : INFO : PROGRESS: at 20.82% examples, 732029 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:44:18,725 : INFO : PROGRESS: at 21.24% examples, 731869 words/s, in_qsize 14, out_qsize 1
# 2017-07-23 16:44:19,733 : INFO : PROGRESS: at 21.68% examples, 732248 words/s, in_qsize 13, out_qsize 3
# 2017-07-23 16:44:20,739 : INFO : PROGRESS: at 22.12% examples, 732922 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:44:21,751 : INFO : PROGRESS: at 22.56% examples, 733139 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:44:22,753 : INFO : PROGRESS: at 22.97% examples, 732779 words/s, in_qsize 13, out_qsize 1
# 2017-07-23 16:44:23,767 : INFO : PROGRESS: at 23.41% examples, 732837 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:44:24,777 : INFO : PROGRESS: at 23.84% examples, 733054 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:44:25,812 : INFO : PROGRESS: at 24.26% examples, 732547 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:44:26,829 : INFO : PROGRESS: at 24.71% examples, 732876 words/s, in_qsize 10, out_qsize 3
# 2017-07-23 16:44:27,832 : INFO : PROGRESS: at 25.14% examples, 733053 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:44:28,834 : INFO : PROGRESS: at 25.55% examples, 732667 words/s, in_qsize 14, out_qsize 1
# 2017-07-23 16:44:29,854 : INFO : PROGRESS: at 25.98% examples, 732405 words/s, in_qsize 14, out_qsize 2
# 2017-07-23 16:44:30,884 : INFO : PROGRESS: at 26.41% examples, 732370 words/s, in_qsize 12, out_qsize 2
# 2017-07-23 16:44:31,888 : INFO : PROGRESS: at 26.84% examples, 732294 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:44:32,910 : INFO : PROGRESS: at 27.26% examples, 732069 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:44:33,920 : INFO : PROGRESS: at 27.68% examples, 731712 words/s, in_qsize 14, out_qsize 3
# 2017-07-23 16:44:34,923 : INFO : PROGRESS: at 28.10% examples, 731534 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:44:35,941 : INFO : PROGRESS: at 28.52% examples, 731187 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:44:36,967 : INFO : PROGRESS: at 28.96% examples, 731335 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:44:37,991 : INFO : PROGRESS: at 29.39% examples, 731271 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:44:39,001 : INFO : PROGRESS: at 29.84% examples, 731466 words/s, in_qsize 10, out_qsize 0
# 2017-07-23 16:44:40,018 : INFO : PROGRESS: at 30.26% examples, 731186 words/s, in_qsize 14, out_qsize 1
# 2017-07-23 16:44:41,030 : INFO : PROGRESS: at 30.69% examples, 730995 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:44:42,042 : INFO : PROGRESS: at 31.12% examples, 730977 words/s, in_qsize 14, out_qsize 1
# 2017-07-23 16:44:43,077 : INFO : PROGRESS: at 31.56% examples, 730825 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:44:44,101 : INFO : PROGRESS: at 32.00% examples, 730731 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:44:45,109 : INFO : PROGRESS: at 32.44% examples, 731008 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:44:46,114 : INFO : PROGRESS: at 32.87% examples, 730852 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:44:47,122 : INFO : PROGRESS: at 33.30% examples, 730817 words/s, in_qsize 10, out_qsize 1
# 2017-07-23 16:44:48,123 : INFO : PROGRESS: at 33.72% examples, 730629 words/s, in_qsize 11, out_qsize 3
# 2017-07-23 16:44:49,141 : INFO : PROGRESS: at 34.15% examples, 730589 words/s, in_qsize 10, out_qsize 3
# 2017-07-23 16:44:50,157 : INFO : PROGRESS: at 34.60% examples, 730677 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:44:51,183 : INFO : PROGRESS: at 35.03% examples, 730397 words/s, in_qsize 14, out_qsize 1
# 2017-07-23 16:44:52,200 : INFO : PROGRESS: at 35.46% examples, 730430 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:44:53,220 : INFO : PROGRESS: at 35.92% examples, 730717 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:44:54,221 : INFO : PROGRESS: at 36.35% examples, 730810 words/s, in_qsize 13, out_qsize 1
# 2017-07-23 16:44:55,240 : INFO : PROGRESS: at 36.80% examples, 730792 words/s, in_qsize 14, out_qsize 1
# 2017-07-23 16:44:56,240 : INFO : PROGRESS: at 37.23% examples, 730828 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:44:57,241 : INFO : PROGRESS: at 37.66% examples, 730838 words/s, in_qsize 13, out_qsize 2
# 2017-07-23 16:44:58,242 : INFO : PROGRESS: at 38.10% examples, 730934 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:44:59,246 : INFO : PROGRESS: at 38.54% examples, 731150 words/s, in_qsize 13, out_qsize 1
# 2017-07-23 16:45:00,248 : INFO : PROGRESS: at 39.01% examples, 731642 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:45:01,258 : INFO : PROGRESS: at 39.45% examples, 731759 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:45:02,282 : INFO : PROGRESS: at 39.90% examples, 731951 words/s, in_qsize 13, out_qsize 1
# 2017-07-23 16:45:03,298 : INFO : PROGRESS: at 40.38% examples, 732767 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:45:04,300 : INFO : PROGRESS: at 40.83% examples, 733220 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:45:05,302 : INFO : PROGRESS: at 41.25% examples, 733195 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:45:06,305 : INFO : PROGRESS: at 41.69% examples, 733424 words/s, in_qsize 14, out_qsize 1
# 2017-07-23 16:45:07,341 : INFO : PROGRESS: at 42.13% examples, 733448 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:45:08,349 : INFO : PROGRESS: at 42.57% examples, 733751 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:45:09,361 : INFO : PROGRESS: at 43.00% examples, 733780 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:45:10,377 : INFO : PROGRESS: at 43.44% examples, 733788 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:45:11,378 : INFO : PROGRESS: at 43.87% examples, 733882 words/s, in_qsize 13, out_qsize 3
# 2017-07-23 16:45:12,387 : INFO : PROGRESS: at 44.30% examples, 734012 words/s, in_qsize 13, out_qsize 1
# 2017-07-23 16:45:13,432 : INFO : PROGRESS: at 44.74% examples, 733836 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:45:14,439 : INFO : PROGRESS: at 45.17% examples, 733821 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:45:15,465 : INFO : PROGRESS: at 45.59% examples, 733652 words/s, in_qsize 14, out_qsize 1
# 2017-07-23 16:45:16,478 : INFO : PROGRESS: at 46.03% examples, 733817 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:45:17,489 : INFO : PROGRESS: at 46.45% examples, 733565 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:45:18,500 : INFO : PROGRESS: at 46.88% examples, 733537 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:45:19,510 : INFO : PROGRESS: at 47.31% examples, 733541 words/s, in_qsize 14, out_qsize 1
# 2017-07-23 16:45:20,530 : INFO : PROGRESS: at 47.74% examples, 733475 words/s, in_qsize 13, out_qsize 2
# 2017-07-23 16:45:21,549 : INFO : PROGRESS: at 48.17% examples, 733429 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:45:22,562 : INFO : PROGRESS: at 48.59% examples, 733324 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:45:23,565 : INFO : PROGRESS: at 49.02% examples, 733265 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:45:24,570 : INFO : PROGRESS: at 49.45% examples, 733267 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:45:25,594 : INFO : PROGRESS: at 49.89% examples, 733277 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:45:26,596 : INFO : PROGRESS: at 50.31% examples, 733060 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:45:27,609 : INFO : PROGRESS: at 50.75% examples, 733175 words/s, in_qsize 13, out_qsize 1
# 2017-07-23 16:45:28,621 : INFO : PROGRESS: at 51.17% examples, 732901 words/s, in_qsize 10, out_qsize 3
# 2017-07-23 16:45:29,634 : INFO : PROGRESS: at 51.61% examples, 732917 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:45:30,636 : INFO : PROGRESS: at 52.04% examples, 733039 words/s, in_qsize 14, out_qsize 1
# 2017-07-23 16:45:31,658 : INFO : PROGRESS: at 52.48% examples, 732973 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:45:32,672 : INFO : PROGRESS: at 52.93% examples, 733073 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:45:33,691 : INFO : PROGRESS: at 53.36% examples, 733022 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:45:34,704 : INFO : PROGRESS: at 53.80% examples, 733121 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:45:35,727 : INFO : PROGRESS: at 54.23% examples, 732981 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:45:36,740 : INFO : PROGRESS: at 54.67% examples, 732975 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:45:37,762 : INFO : PROGRESS: at 55.10% examples, 732803 words/s, in_qsize 14, out_qsize 2
# 2017-07-23 16:45:38,769 : INFO : PROGRESS: at 55.53% examples, 732750 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:45:39,769 : INFO : PROGRESS: at 55.97% examples, 732852 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:45:40,798 : INFO : PROGRESS: at 56.42% examples, 732857 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:45:41,802 : INFO : PROGRESS: at 56.86% examples, 732897 words/s, in_qsize 13, out_qsize 1
# 2017-07-23 16:45:42,809 : INFO : PROGRESS: at 57.31% examples, 733119 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:45:43,827 : INFO : PROGRESS: at 57.75% examples, 733182 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:45:44,838 : INFO : PROGRESS: at 58.19% examples, 733109 words/s, in_qsize 14, out_qsize 1
# 2017-07-23 16:45:45,844 : INFO : PROGRESS: at 58.64% examples, 733259 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:45:46,869 : INFO : PROGRESS: at 59.08% examples, 733185 words/s, in_qsize 11, out_qsize 3
# 2017-07-23 16:45:47,873 : INFO : PROGRESS: at 59.53% examples, 733394 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:45:48,882 : INFO : PROGRESS: at 59.98% examples, 733536 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:45:49,886 : INFO : PROGRESS: at 60.44% examples, 734052 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:45:50,887 : INFO : PROGRESS: at 60.89% examples, 734282 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:45:51,898 : INFO : PROGRESS: at 61.32% examples, 734280 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:45:52,912 : INFO : PROGRESS: at 61.76% examples, 734379 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:45:53,948 : INFO : PROGRESS: at 62.19% examples, 734372 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:45:54,949 : INFO : PROGRESS: at 62.63% examples, 734567 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:45:55,965 : INFO : PROGRESS: at 63.06% examples, 734514 words/s, in_qsize 12, out_qsize 2
# 2017-07-23 16:45:56,965 : INFO : PROGRESS: at 63.48% examples, 734381 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:45:57,992 : INFO : PROGRESS: at 63.84% examples, 733588 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:45:59,014 : INFO : PROGRESS: at 64.27% examples, 733515 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:46:00,027 : INFO : PROGRESS: at 64.69% examples, 733350 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:46:01,042 : INFO : PROGRESS: at 65.13% examples, 733403 words/s, in_qsize 14, out_qsize 1
# 2017-07-23 16:46:02,043 : INFO : PROGRESS: at 65.55% examples, 733405 words/s, in_qsize 13, out_qsize 2
# 2017-07-23 16:46:03,068 : INFO : PROGRESS: at 65.98% examples, 733377 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:46:04,093 : INFO : PROGRESS: at 66.40% examples, 733132 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:46:05,125 : INFO : PROGRESS: at 66.85% examples, 733211 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:46:06,137 : INFO : PROGRESS: at 67.28% examples, 733309 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:46:07,150 : INFO : PROGRESS: at 67.71% examples, 733291 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:46:08,151 : INFO : PROGRESS: at 68.13% examples, 733207 words/s, in_qsize 14, out_qsize 1
# 2017-07-23 16:46:09,154 : INFO : PROGRESS: at 68.56% examples, 733171 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:46:10,167 : INFO : PROGRESS: at 68.98% examples, 733093 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:46:11,175 : INFO : PROGRESS: at 69.40% examples, 732981 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:46:12,194 : INFO : PROGRESS: at 69.86% examples, 733161 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:46:13,200 : INFO : PROGRESS: at 70.29% examples, 733124 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:46:14,226 : INFO : PROGRESS: at 70.71% examples, 732968 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:46:15,235 : INFO : PROGRESS: at 71.15% examples, 732960 words/s, in_qsize 14, out_qsize 1
# 2017-07-23 16:46:16,236 : INFO : PROGRESS: at 71.58% examples, 732886 words/s, in_qsize 14, out_qsize 3
# 2017-07-23 16:46:17,249 : INFO : PROGRESS: at 72.02% examples, 732975 words/s, in_qsize 10, out_qsize 3
# 2017-07-23 16:46:18,257 : INFO : PROGRESS: at 72.46% examples, 733081 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:46:19,278 : INFO : PROGRESS: at 72.90% examples, 733027 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:46:20,313 : INFO : PROGRESS: at 73.35% examples, 733064 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:46:21,313 : INFO : PROGRESS: at 73.78% examples, 733145 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:46:22,338 : INFO : PROGRESS: at 74.20% examples, 732905 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:46:23,354 : INFO : PROGRESS: at 74.63% examples, 732801 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:46:24,354 : INFO : PROGRESS: at 75.06% examples, 732727 words/s, in_qsize 10, out_qsize 3
# 2017-07-23 16:46:25,362 : INFO : PROGRESS: at 75.50% examples, 732853 words/s, in_qsize 12, out_qsize 0
# 2017-07-23 16:46:26,394 : INFO : PROGRESS: at 75.95% examples, 732838 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:46:27,395 : INFO : PROGRESS: at 76.38% examples, 732874 words/s, in_qsize 11, out_qsize 1
# 2017-07-23 16:46:28,405 : INFO : PROGRESS: at 76.82% examples, 732843 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:46:29,433 : INFO : PROGRESS: at 77.26% examples, 732829 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:46:30,443 : INFO : PROGRESS: at 77.70% examples, 732825 words/s, in_qsize 13, out_qsize 3
# 2017-07-23 16:46:31,447 : INFO : PROGRESS: at 78.14% examples, 732847 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:46:32,448 : INFO : PROGRESS: at 78.57% examples, 732823 words/s, in_qsize 11, out_qsize 3
# 2017-07-23 16:46:33,452 : INFO : PROGRESS: at 79.03% examples, 732967 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:46:34,481 : INFO : PROGRESS: at 79.48% examples, 733068 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:46:35,489 : INFO : PROGRESS: at 79.95% examples, 733340 words/s, in_qsize 12, out_qsize 0
# 2017-07-23 16:46:36,505 : INFO : PROGRESS: at 80.41% examples, 733623 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:46:37,539 : INFO : PROGRESS: at 80.84% examples, 733607 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:46:38,543 : INFO : PROGRESS: at 81.29% examples, 733748 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:46:39,561 : INFO : PROGRESS: at 81.73% examples, 733850 words/s, in_qsize 13, out_qsize 1
# 2017-07-23 16:46:40,576 : INFO : PROGRESS: at 82.17% examples, 733972 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:46:41,581 : INFO : PROGRESS: at 82.60% examples, 734025 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:46:42,590 : INFO : PROGRESS: at 83.03% examples, 733968 words/s, in_qsize 13, out_qsize 4
# 2017-07-23 16:46:43,610 : INFO : PROGRESS: at 83.48% examples, 734116 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:46:44,618 : INFO : PROGRESS: at 83.91% examples, 734174 words/s, in_qsize 14, out_qsize 2
# 2017-07-23 16:46:45,622 : INFO : PROGRESS: at 84.35% examples, 734264 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:46:46,642 : INFO : PROGRESS: at 84.76% examples, 734104 words/s, in_qsize 11, out_qsize 3
# 2017-07-23 16:46:47,656 : INFO : PROGRESS: at 85.20% examples, 734146 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:46:48,674 : INFO : PROGRESS: at 85.62% examples, 734047 words/s, in_qsize 10, out_qsize 3
# 2017-07-23 16:46:49,694 : INFO : PROGRESS: at 86.06% examples, 734101 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:46:50,699 : INFO : PROGRESS: at 86.49% examples, 734068 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:46:51,704 : INFO : PROGRESS: at 86.93% examples, 734146 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:46:52,710 : INFO : PROGRESS: at 87.34% examples, 734046 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:46:53,713 : INFO : PROGRESS: at 87.77% examples, 734028 words/s, in_qsize 11, out_qsize 3
# 2017-07-23 16:46:54,721 : INFO : PROGRESS: at 88.21% examples, 734069 words/s, in_qsize 13, out_qsize 1
# 2017-07-23 16:46:55,723 : INFO : PROGRESS: at 88.64% examples, 734130 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:46:56,738 : INFO : PROGRESS: at 89.08% examples, 734155 words/s, in_qsize 10, out_qsize 3
# 2017-07-23 16:46:57,739 : INFO : PROGRESS: at 89.52% examples, 734272 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:46:58,743 : INFO : PROGRESS: at 89.94% examples, 734172 words/s, in_qsize 14, out_qsize 3
# 2017-07-23 16:46:59,745 : INFO : PROGRESS: at 90.38% examples, 734221 words/s, in_qsize 10, out_qsize 3
# 2017-07-23 16:47:00,755 : INFO : PROGRESS: at 90.82% examples, 734236 words/s, in_qsize 13, out_qsize 1
# 2017-07-23 16:47:01,771 : INFO : PROGRESS: at 91.24% examples, 734114 words/s, in_qsize 12, out_qsize 2
# 2017-07-23 16:47:02,787 : INFO : PROGRESS: at 91.69% examples, 734180 words/s, in_qsize 9, out_qsize 1
# 2017-07-23 16:47:03,799 : INFO : PROGRESS: at 92.13% examples, 734281 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:47:04,824 : INFO : PROGRESS: at 92.58% examples, 734299 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:47:05,828 : INFO : PROGRESS: at 93.01% examples, 734279 words/s, in_qsize 10, out_qsize 1
# 2017-07-23 16:47:06,844 : INFO : PROGRESS: at 93.43% examples, 734179 words/s, in_qsize 14, out_qsize 3
# 2017-07-23 16:47:07,858 : INFO : PROGRESS: at 93.88% examples, 734258 words/s, in_qsize 14, out_qsize 1
# 2017-07-23 16:47:08,890 : INFO : PROGRESS: at 94.33% examples, 734284 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:47:09,903 : INFO : PROGRESS: at 94.77% examples, 734268 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:47:10,917 : INFO : PROGRESS: at 95.21% examples, 734274 words/s, in_qsize 13, out_qsize 1
# 2017-07-23 16:47:11,924 : INFO : PROGRESS: at 95.65% examples, 734324 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:47:12,924 : INFO : PROGRESS: at 96.09% examples, 734374 words/s, in_qsize 13, out_qsize 1
# 2017-07-23 16:47:13,927 : INFO : PROGRESS: at 96.53% examples, 734385 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:47:14,935 : INFO : PROGRESS: at 96.98% examples, 734460 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:47:15,956 : INFO : PROGRESS: at 97.41% examples, 734411 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:47:16,958 : INFO : PROGRESS: at 97.86% examples, 734502 words/s, in_qsize 12, out_qsize 1
# 2017-07-23 16:47:17,972 : INFO : PROGRESS: at 98.31% examples, 734568 words/s, in_qsize 10, out_qsize 3
# 2017-07-23 16:47:18,978 : INFO : PROGRESS: at 98.77% examples, 734725 words/s, in_qsize 13, out_qsize 0
# 2017-07-23 16:47:19,987 : INFO : PROGRESS: at 99.22% examples, 734807 words/s, in_qsize 11, out_qsize 2
# 2017-07-23 16:47:21,004 : INFO : PROGRESS: at 99.70% examples, 735057 words/s, in_qsize 14, out_qsize 0
# 2017-07-23 16:47:21,594 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2017-07-23 16:47:21,605 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2017-07-23 16:47:21,608 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2017-07-23 16:47:21,616 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-07-23 16:47:21,619 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-07-23 16:47:21,628 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-07-23 16:47:21,630 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-07-23 16:47:21,630 : INFO : training on 223701450 raw words (171012810 effective words) took 232.6s, 735264 effective words/s
# 2017-07-23 16:47:21,631 : INFO : precomputing L2-norms of word weight vectors
# Freeing the memory...
# 2017-07-23 16:47:23,578 : INFO : saving Word2Vec object under /home/snu/data/Kor_Test_data/models/2017-07-23_16-43-00/output_0, separately None
# 2017-07-23 16:47:23,578 : INFO : storing np array 'syn0' to /home/snu/data/Kor_Test_data/models/2017-07-23_16-43-00/output_0.wv.syn0.npy
# 2017-07-23 16:47:23,626 : INFO : not storing attribute syn0norm
# 2017-07-23 16:47:23,627 : INFO : storing np array 'syn1neg' to /home/snu/data/Kor_Test_data/models/2017-07-23_16-43-00/output_0.syn1neg.npy
# 2017-07-23 16:47:23,677 : INFO : not storing attribute cum_table
# saving the model...
# 2017-07-23 16:47:24,316 : INFO : saved /home/snu/data/Kor_Test_data/models/2017-07-23_16-43-00/output_0
# Testing the model...
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-2-377a1b387d84> in <module>()
#      97         }
#      98
# ---> 99     results = train_and_test(root_train, root_test, output_name, params)
#     100
#     101     print("\nAverage test results: \n")
#
# <ipython-input-2-377a1b387d84> in train_and_test(root_train, root_test, output_name, params)
#      54     sim=0
#      55     sim2=0
# ---> 56     num_tests=len(filenames)
#      57     mw=0
#      58     total_num_pairs=0
#
# UnboundLocalError: local variable 'filenames' referenced before assignment
